# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadRafif22/PCVK_Genap_2023/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IDENTITAS MAHASISWA
#
# Nama : Ahmad Rafif Alaudin
#
# NIM : 2041720230
#
# Kelas : TI 3G
#
# Absen : 02

# %% [markdown]
# # F. TUGAS PRAKTIKUM

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Library

import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ## 1. Buat Gamma Correction sesuai dengan petunjuk berikut
#
# Percobaan ini akan meminta anda membuat Gamma Correction. Pada percobaan ini, nilai
# Gamma akan diset dengan meminta masukan dari pengguna. Berikut adalah kode untuk
# meminta masukan nilai dari pengguna. Lanjutkan kode tersebut dengan membuat image
# dengan gamma correction sesuai rumus yang telah diberikan.

# %%
print(' Gamma Correction pada citra ') 
print('----------------------------------') 
try: 
 gamma = int(input('Masukkan nilai Gamma: ')) 
except ValueError: 
 print('Error, not a number')

original1 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 3/female.tiff')
gamma_image = np.zeros(original1.shape, original1.dtype)

gamma_image = np.power(original1/255.0, 1/gamma)
gamma_image = gamma_image * 255.0
# Convert back to uint8
gamma_image = np.uint8(gamma_image)

final_frame1 = cv.hconcat((original1, gamma_image))
cv2_imshow(final_frame1)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FF456C19520>

# %% [markdown]
# ## 2. Buat Simulasi Image Depth
#
# Percobaan ini digunakan sebagai simulasi dari proses kuantisasi citra. Pada kuantisasi citra,
# pixel dapat direpresentasikan dengan n-bit kedalaman (default menggunakan 8-bit). Pada
# pixel 8-bit, warna yang memungkinkan adalah 256 warna, dari 0 (0000 0000) hingga
# 255(1111 1111). Pada pixel 7-bit, warna yang memungkinkan adalah 128 warna, dari 0 (000
# 0000) hingga 127 (111 1111). Kemungkinan warna didapat dari pangkat 2 jumlah bit. Jika
# 7bit, maka jumlah warnanya adalah 27
#  = 128, dst.

# %%
bit_depth=2
level = 255 / (pow(2,bit_depth)-1) 
original2 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 3/female.tiff', cv.IMREAD_GRAYSCALE) 
depth_image = np.zeros(original2.shape, original2.dtype)
 
depth_image = np.array(np.round((original2/level))*level, dtype='uint8')

final_frame2 = cv.hconcat((original2, depth_image))
cv2_imshow(final_frame2)
# Out:
# <PIL.Image.Image image mode=L size=512x256 at 0x7FF454225520>

# %% [markdown]
# ## 3. Buat modul Average Denoising
#
# Buat modul average denoising sesuai dengan rumus yang telah diberikan pada sub bab
# sebelumnya.
# Citra asli sudah disediakan pada /images/galaxy.jpg.
# 100 Citra dengan Gaussian Noise sudah disediakan pada /images/noises/*.jpg
# Anda dapat menggunakan code berikut untuk membaca semua image dalam satu folder ,
# gunakan modul glob (import glob).

# %%
import math 
def PSNR(img1, img2):
    mse = np.mean((img1 - img2) ** 2) 
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * math.log10(max_pixel / math.sqrt(mse)) 
    return psnr 

# image asli
img_asli = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/galaxy.jpg')

cv_img = [] 
for img in glob.glob('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/noises/*.jpg'): 
  n= cv.imread(img) 
  cv_img.append(n) 

denoised_img = np.zeros(cv_img[0].shape)

# %%
# jumlah 5

jml = 5
for i in range(jml):
  denoised_img = denoised_img+cv_img[i]
denoised_img = np.uint16(denoised_img/jml)

psnr = PSNR(img_asli,denoised_img)

print('nilai psnr nya adalah : ',psnr,' dB')

cv2_imshow(cv_img[0])
cv2_imshow(denoised_img)
# Out:
# nilai psnr nya adalah :  15.693041586892004  dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282BE0>
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF4462829D0>

# %%
# jumlah 30

jml = 30
for i in range(jml):
  denoised_img = denoised_img+cv_img[i]
denoised_img = np.uint16(denoised_img/jml)

psnr = PSNR(img_asli,denoised_img)

print('nilai psnr nya adalah : ',psnr,' dB')

cv2_imshow(cv_img[0])
cv2_imshow(denoised_img)
# Out:
# nilai psnr nya adalah :  19.872561820452816  dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF4461A67C0>
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282D60>

# %%
# jumlah 60

jml = 60
for i in range(jml):
  denoised_img = denoised_img+cv_img[i]
denoised_img = np.uint16(denoised_img/jml)

psnr = PSNR(img_asli,denoised_img)

print('nilai psnr nya adalah : ',psnr,' dB')

cv2_imshow(cv_img[0])
cv2_imshow(denoised_img)
# Out:
# nilai psnr nya adalah :  19.53420436918956  dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282BE0>
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282F40>

# %%
# jumlah 80

jml = 80
for i in range(jml):
  denoised_img = denoised_img+cv_img[i]
denoised_img = np.uint16(denoised_img/jml)

psnr = PSNR(img_asli,denoised_img)

print('nilai psnr nya adalah : ',psnr,' dB')

cv2_imshow(cv_img[0])
cv2_imshow(denoised_img)
# Out:
# nilai psnr nya adalah :  19.63167743375616  dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF4462829D0>
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282DF0>

# %%
# jumlah 100

jml = 100
for i in range(jml):
  denoised_img = denoised_img+cv_img[i]
denoised_img = np.uint16(denoised_img/jml)

psnr = PSNR(img_asli,denoised_img)

print('nilai psnr nya adalah : ',psnr,' dB')

cv2_imshow(cv_img[0])
cv2_imshow(denoised_img)
# Out:
# nilai psnr nya adalah :  19.692736678313533  dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF446282AC0>
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FF4463AD310>

# %% [markdown]
# Kesimpulan :
#
# - makin tinggi nilai PSNR, makin baik kualitas citra hasil denoise-nya.
#
# - makin tinggi nilai MSE nya semakin besar perbedaan citranya.

# %% [markdown]
# ## 4. Buat image masking untuk image berikut. Image kiri adalah image asli (images/couple.tiff), sedangkan image paling kanan adalah hasilnya:

# %%
original4 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/couple.tiff')
black_img = np.zeros(original4.shape, dtype=np.uint8)

cv.circle(black_img,center=(65,50),radius=25,color=(255,255,255),thickness=50)
cv.circle(black_img,center=(185,50),radius=25,color=(255,255,255),thickness=50)

original41 = ~ original4

result_AND = ~ (black_img & original41)

final_frame4 = cv.hconcat((original4, black_img, result_AND))
cv2_imshow(final_frame4)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7FF446248640>

# %% [markdown]
# ## 5.  Lakukan percobaan menggunakan operator lain dan tunjukkan hasilnya pada modul ini. Tuliskan hasil analisa anda kenapa citra keluarannya seperti itu.

# %%
# Operator OR

original4 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/couple.tiff')
black_img = np.zeros(original4.shape, dtype=np.uint8)

cv.circle(black_img,center=(65,50),radius=25,color=(255,255,255),thickness=50)
cv.circle(black_img,center=(185,50),radius=25,color=(255,255,255),thickness=50)

result_OR = black_img | original4

final_frame4 = cv.hconcat((original4, black_img, result_OR))
cv2_imshow(final_frame4)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7FF4462578E0>

# %%
# Operator NOT

original4 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/couple.tiff')
black_img = np.zeros(original4.shape, dtype=np.uint8)

cv.circle(black_img,center=(65,50),radius=25,color=(255,255,255),thickness=50)
cv.circle(black_img,center=(185,50),radius=25,color=(255,255,255),thickness=50)

result_NOT = original4

result_NOT = ~ black_img 

final_frame4 = cv.hconcat((original4, black_img, result_NOT))
cv2_imshow(final_frame4)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7FF446323100>

# %%
# Operator NAND

original4 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/couple.tiff')
black_img = np.zeros(original4.shape, dtype=np.uint8)

cv.circle(black_img,center=(65,50),radius=25,color=(255,255,255),thickness=50)
cv.circle(black_img,center=(185,50),radius=25,color=(255,255,255),thickness=50)

result_NAND = ~ (black_img & original4)

final_frame4 = cv.hconcat((original4, black_img, result_NAND))
cv2_imshow(final_frame4)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7FF4463AD310>

# %%
# Operator XOR

original4 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 5/couple.tiff')
black_img = np.zeros(original4.shape, dtype=np.uint8)

cv.circle(black_img,center=(65,50),radius=25,color=(255,255,255),thickness=50)
cv.circle(black_img,center=(185,50),radius=25,color=(255,255,255),thickness=50)

result_XOR = black_img ^ original4

final_frame4 = cv.hconcat((original4, black_img, result_XOR))
cv2_imshow(final_frame4)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7FF446282EB0>
