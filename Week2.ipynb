# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadRafif22/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Praktikum

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 2/kitten01.JPG')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 2/kitten01.JPG', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #ubah-ubah ukutan (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300],[200, 200],[400, 300],[200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Pertanyaan

# %% [markdown]
# 1.  Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# ### Jawaban

# %% [markdown]
# 1. matplotlib merupakan sebuah library yang digunakan untuk melakukan visualisasi data, termasuk data citra, dengan menggunakan library ini kita dapat dengan lebih mudah melakukan visualisasi data seperti menampilkan data menggunakan `imshow()` dan me-resize data dengan menggunakan `figure()`
#
# 2. perbedaannya adalah dari segi ukuran memori yang digunakan untuk menyimpan setiap elemen array, dan rentang nilai yang dapat disimpan. selain itu juga mempengaruhi kinerja komputasi. tipe data int16 dapat menyimpan elemen array lebih sedikit sehingga kinerja komputasi yang dilakukan dapat lebih cepat. sedangkan tipe data int 32 dapat menyimpam elemen array lebih banyak sehingga kinerja komputasi yang dilakukan lebih berat.
#
# 3. "google.colab.patches import cv2_imshow" digunakan untuk menampilkan gambar dalam google colab menggunakan OpenCV dengan lebih mudah.
#
# 4. “skimage import io” adalah library yang digunakan untuk read dan write data citra dengan berbagai format, seperti JPG, PNG dll. selain itu library ini juga dapat digunakan untuk menyimpan data citra menggunakan fungsi `imsave()`

# %% [markdown]
# ## TUGAS
#
# berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut:

# %% [markdown]
# #### 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

tinggi1 = img3.shape[0]
lebar1 = img3.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi1," x ",lebar1)
plt.imshow(img3)
# Out:
# resolusi image: tinggi x lebar =  627  x  670

# %%
tinggi2 = img5.shape[0]
lebar2 = img5.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi2," x ",lebar2)
plt.imshow(img5)
# Out:
# resolusi image: tinggi x lebar =  627  x  670

# %% [markdown]
# berdasarkan perbandingan diatas dapat disimpulkan bahwa ukurannya tidak berubah

# %% [markdown]
# #### 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
# Red-Blue
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

img7[:,:,1] = 0
plt.imshow(img7)

# %%
# Green-Blue
img8 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

img8[:,:,0] = 0
plt.imshow(img8)

# %% [markdown]
# #### 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
img9 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

crop = img9[20:115,25:120]
plt.imshow(crop)

# %% [markdown]
# #### 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
# Red saja
img10 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

img10[:,:,1] = 0
img10[:,:,2] = 0

crop10 = img10[5:30,:]
plt.imshow(crop10)

# %% [markdown]
# #### 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
img11 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

cv.rectangle(img11,pt1=(100,150),pt2=(400,450),color=(255,255,0),thickness=5)
cv.rectangle(img11,pt1=(500,300),pt2=(600,600),color=(0,255,0),thickness=5)
cv.rectangle(img11,pt1=(384,0),pt2=(200,200),color=(0,255,255),thickness=5)
cv.rectangle(img11,pt1=(245,100),pt2=(300,350),color=(255,255,255),thickness=5)
cv.rectangle(img11,pt1=(200,200),pt2=(460,460),color=(0,0,0),thickness=5)

plt.imshow(img11)

# %% [markdown]
# #### 6. Tampilkan image dengan posisi terbalik!

# %%
img12 = cv.flip(img11,0)
plt.imshow(img12)

# %% [markdown]
# #### 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
# import image
img13 = cv.imread('/content/drive/MyDrive/Kuliah/Semester 6/lain lain/PVCK/Pertemuan 2/bukanFotoPas.jpg')
img14 = cv.cvtColor(img13,cv.COLOR_BGR2RGB)  #konveris channel GRB -> RGB

# %%
cv.circle(img14,center=(770,360),radius=150,color=(255,0,0),thickness=15)
plt.imshow(img14)

# %% [markdown]
# #### 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
font = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(img14, text='Ahmad Rafif Alaudin',org=(10,860),fontFace=font,fontScale=5,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img14)
